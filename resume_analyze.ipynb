# %% [markdown]
# Getting the Text from PDF

# %%
# %pip install pdfplumber pytesseract pdf2image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        # Try direct text extraction
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text

        if text.strip():
            return text.strip()
    except Exception as e:
        print(f"Direct text extraction failed: {e}")

    # Fallback to OCR for image-based PDFs
    print("Falling back to OCR for image-based PDF.")
    try:
        images = convert_from_path(pdf_path)
        for image in images:
            page_text = pytesseract.image_to_string(image)
            text += page_text + "\n"
    except Exception as e:
        print(f"OCR failed: {e}")

    return text.strip()

# %%
pdf_path = "C:\\Users\\akmde\\OneDrive\\Desktop\\resume_analyzer\\uem mock cv (1) (1) 1o1.pdf"
resume_text = extract_text_from_pdf(pdf_path)

print("\nExtracted Text from PDF:")
print(resume_text)
# Out:
# Extracted Text from PDF:
# ANKIT MISHRA
# Kolkata , West Bengal
# ankitmishrasince2004@gmail.com
# 9339549425
# PROFILE
# I am a programmer who is also deeply passionate about software engineering and blockchain. I am currently pursuing B.Tech. in Computer
# Science and Engineering(IoT,CS,BT), and I am actively involved in projects that revolve around software engineering. Additionally, I have a keen
# interest in machine learning and artificial intelligence and have worked on some related projects.
# PROJECT WORKS
# Online Resume builder website
# I created an online resume builder website using HTML, CSS, and JavaScript that allows users to design and generate professional resumes with
# ease. The platform features a user-friendly interface and customizable templates to cater to diverse needs.
# University of Engineering and Management
# Currency Converter website
# ...

# %% [markdown]
# Setting up the GenAI API

# %%
# %pip install google-genai python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/760.6 kB ? eta -:--:--
#    ---------------------------------------- 760.6/760.6 kB 19.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ----- ---------------------------------- 1/8 [tenacity]
#    ---------- ----------------------------- 2/8 [sniffio]
#    --------------- ------------------------ 3/8 [pyasn1]
#    --------------- ------------------------ 3/8 [pyasn1]
#    -------------------- ------------------- 4/8 [distro]
#    ------------------------- -------------- 5/8 [pyasn1-modules]
# ...

# %%
from google import genai

client = genai.Client(api_key="AIzaSyDR5yNIEUjZelKrAVx6jDTyopL-Pn6DgEY")

response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI analyzes data to find patterns and make predictions.

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview", contents="What is the capital of India?"
)
print(response.text)
# Out:
# The capital of India is **New Delhi**.

# %% [markdown]
# RESUME ANALYSIS

# %%
def analyze_resume(resume_text, job_description=None):
    if not resume_text:
        return {"error": "Resume text is required for analysis."}
    
    client = genai.Client(api_key=("AIzaSyDR5yNIEUjZelKrAVx6jDTyopL-Pn6DgEY"))
    
    base_prompt = f"""
    You are an experienced HR with Technical Experience in the field of any one job role from Data Science, Data Analyst, DevOPS, Machine Learning Engineer, Prompt Engineer, AI Engineer, Full Stack Web Development, Big Data Engineering, Marketing Analyst, Human Resource Manager, Software Developer your task is to review the provided resume.
    Please share your professional evaluation on whether the candidate's profile aligns with the role.ALso mention Skills he already have and suggest some skills to improve his resume , alos suggest some course he might take to improve the skills. Highlight the strengths and weaknesses too.

    Resume:
    {resume_text}
    """

    if job_description:
        base_prompt += f"""
        Additionally, compare this resume to the following job description:
        
        Job Description:
        {job_description}
        
        Highlight the strengths and weaknesses of the applicant in relation to the specified job requirements.
        """

    response = client.models.generate_content(
    model="gemini-3-flash-preview", contents=base_prompt
)

    analysis = response.text.strip()
    return analysis

# %%
print(analyze_resume(resume_text))
# Out:
# Hello Ankit. As an HR professional with a technical background in **Full Stack Web Development**, I have reviewed your resume.
#
# Since you are currently in your B.Tech (2022-2026) and have already completed projects using React and JavaScript, you are on the right track for a **Junior Full Stack Developer or Web Development Intern** role. However, your profile currently leans heavily toward the "Front-End" side, and to be considered a "Full Stack" candidate, we need to see more depth in backend, databases, and DevOps.
#
# ---
#
# ### **1. Professional Evaluation**
# **Current Standing:** Early-stage Developer / Student.
# **Alignment with Full Stack Role:** **40%.**
# ...
